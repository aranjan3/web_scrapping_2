# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Load the webpage content
url = "https://en.wikipedia.org/wiki/List_of_active_Indian_military_aircraft"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
#Parse the webpage content
soup = BeautifulSoup(response.text, "html.parser")
table = soup.find_all("table",class_="wikitable")

# %%
# Select the first relevant table
table = table[0]

# %%
# Extract rows
data = []
for row in table.find_all("tr"):
    cols = row.find_all("td")
    if cols:  # If the row contains data
        row_data = []
        for col in cols:
            # Extract text inside <a> tag if present, else get normal text
            link = col.find("a")
            if link:
                row_data.append(link.text.strip())  # Extract aircraft name from <a> tag
            else:
                row_data.append(col.text.strip())  # Extract normal text
        data.append(row_data)

# %%
# Convert the data into a pandas DataFrame
df=pd.DataFrame(data)

# %%
# Drop rows with missing values
df=df.dropna()

# %%
#drop last two irrelevent columns
df = df.iloc[:, :-2]
df
# Out:
#                                0               1                     2  \
# 0                Dassault Rafale          France             Multirole
# 2                      HAL Tejas           India             Multirole
# 5                Sukhoi Su-30MKI          Russia             Multirole
# 6                 Mikoyan MiG-29    Soviet Union             Multirole
# 8           Dassault Mirage 2000          France             Multirole
# 10                SEPECAT Jaguar  United Kingdom                Attack
# 13       Mikoyan-Gurevich MiG-21    Soviet Union           Interceptor
# 14                  Embraer R-99          Brazil                 AEW&C
# 15                   Beriev A-50    Soviet Union                 AEW&C
# 16                    Boeing 707   United States                SIGINT
# 21                Ilyushin Il-78    Soviet Union     aerial refuelling
# 22                    Boeing 777   United States         VIP transport
# 23            Embraer Legacy 600          Brazil         VIP transport
# 24                   Boeing C-17   United States   strategic airlifter
# 25                Ilyushin Il-76    Soviet Union   strategic airlifter
# 26         C-130J Super Hercules   United States    tactical airlifter
# 27                   Airbus A321          Europe             transport
# 28                 Antonov An-32    Soviet Union    tactical airlifter
# 29                  Airbus C-295           Spain    tactical airlifter
# 30        Hawker Siddeley HS 748  United Kingdom    tactical airlifter
# 31                   Dornier 228         Germany    tactical airlifter
# 32                  Boeing AH-64   United States                attack
# 33                     Mil Mi-24          Russia                attack
# 34                  HAL Prachand           India                attack
# 35                     HAL Rudra           India                attack
# 36                 CH-47 Chinook   United States             transport
# 37                     Mil Mi-17          Russia               utility
# 38                     HAL Dhruv           India               utility
# 39  HAL Light Utility Helicopter           India               utility
# 40                  Alouette III    France/India               liaison
# 43                      BAE Hawk  United Kingdom      Advanced trainer
# 44                     HAL Kiran           India  Intermediate trainer
# 45                    HAL HTT-40           India         Basic trainer
# 46                  Pilatus PC-7     Switzerland         Basic trainer
# 47               Pipistrel Virus        Slovenia     Ab initio trainer
# 48                     IAI Heron          Israel          Surveillance
# 51                   MQ-9 Reaper   United States          Surveillance
# 52                        ALS-50           India    loitering munition
#
#                      3
# 0                   DH
# 2                 Mk.1
# 5   Su-30MKI Flanker H
# 6              Fulcrum
# 8               -2000H
# 10                  IB
# 13        MiG-21 Bison
# 14           Netra Mk1
# 15              A-50EI
# 16    707-337C Phalcon
# 21            Il-78MKI
# 22           777-300ER
# 23
# 24
# 25             Il-76MD
# 26           C-130J-30
# 27            A321-200
# 28
# 29              C-295W
# 30
# 31             228-201
# 32              AH-64E
# 33            Mi-25/35
# 34
# 35
# 36              CH-47F
# 37            Mi-17V-5
# 38
# 39
# 40              Chetak
# 43            Hawk 132
# 44
# 45
# 46               Mk II
# 47
# 48                Mk 1
# 51         SkyGuardian
# 52

# %%
#find missing cells
missing = df.isnull().sum()
missing
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
#adding headers
headers= ['Aircraft', 'Origin', 'Type', 'Variant']
df.columns = headers
df
# Out:
#                         Aircraft          Origin                  Type  \
# 0                Dassault Rafale          France             Multirole
# 2                      HAL Tejas           India             Multirole
# 5                Sukhoi Su-30MKI          Russia             Multirole
# 6                 Mikoyan MiG-29    Soviet Union             Multirole
# 8           Dassault Mirage 2000          France             Multirole
# 10                SEPECAT Jaguar  United Kingdom                Attack
# 13       Mikoyan-Gurevich MiG-21    Soviet Union           Interceptor
# 14                  Embraer R-99          Brazil                 AEW&C
# 15                   Beriev A-50    Soviet Union                 AEW&C
# 16                    Boeing 707   United States                SIGINT
# 21                Ilyushin Il-78    Soviet Union     aerial refuelling
# 22                    Boeing 777   United States         VIP transport
# 23            Embraer Legacy 600          Brazil         VIP transport
# 24                   Boeing C-17   United States   strategic airlifter
# 25                Ilyushin Il-76    Soviet Union   strategic airlifter
# 26         C-130J Super Hercules   United States    tactical airlifter
# 27                   Airbus A321          Europe             transport
# 28                 Antonov An-32    Soviet Union    tactical airlifter
# 29                  Airbus C-295           Spain    tactical airlifter
# 30        Hawker Siddeley HS 748  United Kingdom    tactical airlifter
# 31                   Dornier 228         Germany    tactical airlifter
# 32                  Boeing AH-64   United States                attack
# 33                     Mil Mi-24          Russia                attack
# 34                  HAL Prachand           India                attack
# 35                     HAL Rudra           India                attack
# 36                 CH-47 Chinook   United States             transport
# 37                     Mil Mi-17          Russia               utility
# 38                     HAL Dhruv           India               utility
# 39  HAL Light Utility Helicopter           India               utility
# 40                  Alouette III    France/India               liaison
# 43                      BAE Hawk  United Kingdom      Advanced trainer
# 44                     HAL Kiran           India  Intermediate trainer
# 45                    HAL HTT-40           India         Basic trainer
# 46                  Pilatus PC-7     Switzerland         Basic trainer
# 47               Pipistrel Virus        Slovenia     Ab initio trainer
# 48                     IAI Heron          Israel          Surveillance
# 51                   MQ-9 Reaper   United States          Surveillance
# 52                        ALS-50           India    loitering munition
#
#                Variant
# 0                   DH
# 2                 Mk.1
# 5   Su-30MKI Flanker H
# 6              Fulcrum
# 8               -2000H
# 10                  IB
# 13        MiG-21 Bison
# 14           Netra Mk1
# 15              A-50EI
# 16    707-337C Phalcon
# 21            Il-78MKI
# 22           777-300ER
# 23
# 24
# 25             Il-76MD
# 26           C-130J-30
# 27            A321-200
# 28
# 29              C-295W
# 30
# 31             228-201
# 32              AH-64E
# 33            Mi-25/35
# 34
# 35
# 36              CH-47F
# 37            Mi-17V-5
# 38
# 39
# 40              Chetak
# 43            Hawk 132
# 44
# 45
# 46               Mk II
# 47
# 48                Mk 1
# 51         SkyGuardian
# 52

# %%
df.to_csv('indian_aircraft.csv', index=False)
